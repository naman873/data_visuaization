# %%
import numpy as np
import matplotlib.pyplot  as plt

# %%
a=np.linspace(1,100,3)

# %%
a.dtype
# Out:
# dtype('float64')

# %%
plt.plot(a)

# %%
x=[1,2,3,2]
y=[1,2,3,4]

x1=[2,4,5]
y1=[2,5,9]

# %%
plt.figure()
plt.plot(x,y,c="black",label="first_line")
plt.plot(x1,y1,label="second_line")
plt.title("Test \n Check it out")
plt.xlabel("space")
plt.ylabel("price")
plt.legend()
plt.show()
